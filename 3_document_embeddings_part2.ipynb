# %% [markdown]
# # Using flair

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import torch

from flair.data import Sentence
from flair.embeddings import (
    DocumentPoolEmbeddings,
    FlairEmbeddings, WordEmbeddings,
    ELMoEmbeddings, BertEmbeddings
)

# %% [markdown]
# # Test on pubmed data

# %%
embeddings = DocumentPoolEmbeddings([
    FlairEmbeddings("pubmed-forward"),
    FlairEmbeddings("pubmed-backward"),
    ELMoEmbeddings("pubmed"),
    BertEmbeddings("bert-large-uncased"),
])

# %%
pubmed_data = pd.concat([
    pd.read_json(f"data/medline/{medline_file}") for medline_file in
    ["medline_2016.json", "medline_2017.json", "medline_2018.json"]])

pubmed_data.head()
# Out:
#                                             abstract  \
# 0  OBJECTIVE: To investigate whether there is a a...
# 1  OBJECTIVE: To determine the cardiac and renal ...
# 2  OBJECTIVE: To observe field potentials (FPs) a...
# 3  OBJECTIVE: To study the antitumour effects of ...
# 4  <AbstractText>The preparation of affinity memb...
#
#                         doi      pmid                  timestamp  \
# 0                            19254455 2019-03-06 11:25:42.344605
# 1                            19102882 2019-03-06 11:25:28.159770
# 2                            19102898 2019-03-06 11:25:28.161049
# 3                            21223742 2019-03-06 11:27:31.019968
# 4  10.1163/092050610X538731  21092422 2019-03-06 11:27:26.740139
#
#                                                title                 type  \
# 0  [Association between RsaI and AluI polymorphis...  ['Journal Article']
# 1  [Cardiac and renal arteriolar pathological cha...  ['Journal Article']
# 2  [Cardiac field potentials and activation seque...  ['Journal Article']
# 3  [Investigation on the mechanisms of p15INK4B g...  ['Journal Article']
# 4  Performance of protein-A-based affinity membra...  ['Journal Article']
#
#    year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
pubmed_data.title.shape
# Out:
# (253308,)

# %%
print(pubmed_data.title.values[0])
# Out:
# [Association between RsaI and AluI polymorphism in the estrogen receptor beta gene and primary hepatocellular carcinoma.].

# %%
def preproc(text, limit=512):
    # NOTE: character `limit` is required by BERT
    return (
        text.replace("[", "")
            .replace("]", "")
            .lower()[:limit]
    )

print(preproc(pubmed_data.title.values[0]))
# Out:
# association between rsai and alui polymorphism in the estrogen receptor beta gene and primary hepatocellular carcinoma..

# %%
pubmed_corpus = [
    Sentence(text) for text in
    pubmed_data.title.apply(preproc).head(10_000)
]

# %%
query = [
    Sentence(text) for text in
    [
        "Searching for the causal effects of body mass index in over 300 000 participants in UK Biobank, using Mendelian randomization.",
        "Prioritizing putative influential genes in cardiovascular disease susceptibility by applying tissue-specific Mendelian randomization.",
        "Longitudinal analysis strategies for modelling epigenetic trajectories",
        "FATHMM-XF: accurate prediction of pathogenic point mutations via extended features",
        "PhenoSpD: an integrated toolkit for phenotypic correlation estimation and multiple testing correction using GWAS summary statistics.",
        "LD Hub: a centralized database and web interface to perform LD score regression that maximizes the potential of summary level GWAS data for SNP heritability and genetic correlation analysis.",
        "MELODI: Mining Enriched Literature Objects to Derive Intermediates",
        "The MR-Base platform supports systematic causal inference across the human phenome",
    ]
]

# %%
for text in query + pubmed_corpus:
    embeddings.embed(text)

# %%
cos = torch.nn.CosineSimilarity(dim=0, eps=1e-6)

# %%
cos_scores = []
for query_id, query_text in enumerate(query):
    cos_res = [
        {
            "query_id": query_id,
            "target_id": target_id,
            "score": cos(query_text.embedding, 
                         target_text.embedding).item()
        }
        for target_id, target_text in enumerate(pubmed_corpus)
    ]
    cos_scores.append(cos_res)
    
cos_scores = pd.concat(pd.DataFrame(x) for x in cos_scores)

# %%
cos_scores.head()
# Out:
#    query_id     score  target_id
# 0         0  0.646998          0
# 1         0  0.640018          1
# 2         0  0.652958          2
# 3         0  0.678970          3
# 4         0  0.632604          4

# %%
n = 5

for query_id, query_text in enumerate(query):
    print(f"# Query {query_id}")
    print(query_text)
    
    top_n = (
        cos_scores
          .query(f"query_id == {query_id}")
          .sort_values("score", ascending=False)
          .head(n)
    )
    for target_id, target_score in zip(top_n.target_id, top_n.score):
        print(f"  ## Candidate {target_id}, score {target_score}")
        print(f"  {pubmed_corpus[target_id]}\n")
    print("\n\n")
# Out:
# # Query 0
# Sentence: "Searching for the causal effects of body mass index in over 300 000 participants in UK Biobank, using Mendelian randomization." - 20 Tokens
#   ## Candidate 1835, score 0.8232989311218262
#   Sentence: "review of statistical methodologies for the detection of parent-of-origin effects in family trio genome-wide association data with binary disease traits." - 20 Tokens
#
#   ## Candidate 6101, score 0.8221418857574463
#   Sentence: "the association between lower educational attainment and depression owing to shared genetic effects? results in ~25,000 subjects." - 17 Tokens
#
#   ## Candidate 3903, score 0.8055606484413147
#   Sentence: "network mendelian randomization: using genetic variants as instrumental variables to investigate mediation in causal pathways." - 15 Tokens
#
#   ## Candidate 7759, score 0.802967369556427
#   Sentence: "susceptibility to male infertility: replication study in japanese men looking for an association with four gwas-derived loci identified in european men." - 21 Tokens
#
#   ## Candidate 9251, score 0.801934003829956
#   Sentence: "a large multiethnic genome-wide association study of prostate cancer identifies novel risk variants and substantial ethnic differences." - 17 Tokens
#
#
#
#
# # Query 1
# Sentence: "Prioritizing putative influential genes in cardiovascular disease susceptibility by applying tissue-specific Mendelian randomization." - 13 Tokens
#   ## Candidate 6989, score 0.8146920204162598
#   Sentence: "novel genes affecting blood pressure detected via gene-based association analysis." - 10 Tokens
#
#   ## Candidate 3903, score 0.810567319393158
#   Sentence: "network mendelian randomization: using genetic variants as instrumental variables to investigate mediation in causal pathways." - 15 Tokens
#
#   ## Candidate 7410, score 0.7949574589729309
#   Sentence: "resequencing and association analysis of coding regions at twenty candidate genes suggest a role for rare risk variation at akap9 and protective variation at nrxn1 in schizophrenia susceptibility." - 28 Tokens
#
#   ## Candidate 1784, score 0.7936668992042542
#   Sentence: "improved performance of epidemiologic and genetic risk models for rheumatoid arthritis serologic phenotypes using family history." - 16 Tokens
#
#   ## Candidate 1835, score 0.7936553955078125
#   Sentence: "review of statistical methodologies for the detection of parent-of-origin effects in family trio genome-wide association data with binary disease traits." - 20 Tokens
#
#
#
#
# # Query 2
# Sentence: "Longitudinal analysis strategies for modelling epigenetic trajectories" - 7 Tokens
#   ## Candidate 6236, score 0.7577008605003357
#   Sentence: "improving the rank precision of population health measures for small areas with longitudinal and joint outcome models." - 17 Tokens
#
#   ## Candidate 384, score 0.756220817565918
#   Sentence: "a fast algorithm for learning epistatic genomic relationships." - 8 Tokens
#
#   ## Candidate 1683, score 0.7520811557769775
#   Sentence: "rapid assessment and visualization of normality in high-content and other cell-level data and its impact on the interpretation of experimental results." - 21 Tokens
#
#   ## Candidate 2700, score 0.7514883875846863
#   Sentence: "a multi-poisson dynamic mixture model to cluster developmental patterns of gene expression by rna-seq." - 14 Tokens
#
#   ## Candidate 6488, score 0.7500415444374084
#   Sentence: "analyzing long-term correlated stochastic processes by means of recurrence networks: potentials and pitfalls." - 13 Tokens
#
#
#
#
# # Query 3
# Sentence: "FATHMM-XF: accurate prediction of pathogenic point mutations via extended features" - 10 Tokens
#   ## Candidate 167, score 0.857241690158844
#   Sentence: "spine-d: accurate prediction of short and long disordered regions by a single neural-network based method." - 15 Tokens
#
#   ## Candidate 1890, score 0.833526074886322
#   Sentence: "predppcrys: accurate prediction of sequence cloning, protein production, purification and crystallization propensity from protein sequences using multi-step heterogeneous feature fusion and selection." - 22 Tokens
#
#   ## Candidate 4340, score 0.8298888802528381
#   Sentence: "qslimfinder: improved short linear motif prediction using specific query protein data." - 11 Tokens
#
#   ## Candidate 9390, score 0.8269925713539124
#   Sentence: "integrating full spectrum of sequence features into predicting functional microrna-mrna interactions." - 11 Tokens
#
#   ## Candidate 6265, score 0.825610876083374
#   Sentence: "sv-autopilot: optimized, automated construction of structural variation discovery and benchmarking pipelines." - 11 Tokens
#
#
#
#
# # Query 4
# Sentence: "PhenoSpD: an integrated toolkit for phenotypic correlation estimation and multiple testing correction using GWAS summary statistics." - 16 Tokens
#   ## Candidate 1835, score 0.8448261022567749
#   Sentence: "review of statistical methodologies for the detection of parent-of-origin effects in family trio genome-wide association data with binary disease traits." - 20 Tokens
#
#   ## Candidate 8276, score 0.8371502161026001
#   Sentence: "an empiric weight computation for record linkage using linearly combined fields' similarity scores." - 13 Tokens
#
#   ## Candidate 6265, score 0.83188796043396
#   Sentence: "sv-autopilot: optimized, automated construction of structural variation discovery and benchmarking pipelines." - 11 Tokens
#
#   ## Candidate 160, score 0.8313889503479004
#   Sentence: "finding differentially expressed genes in high dimensional data: rank based test statistic via a distance measure." - 16 Tokens
#
#   ## Candidate 1409, score 0.8296916484832764
#   Sentence: "wfabc: a wright-fisher abc-based approach for inferring effective population sizes and selection coefficients from time-sampled data." - 16 Tokens
#
#
#
#
# # Query 5
# Sentence: "LD Hub: a centralized database and web interface to perform LD score regression that maximizes the potential of summary level GWAS data for SNP heritability and genetic correlation analysis." - 29 Tokens
#   ## Candidate 1835, score 0.8454244136810303
#   Sentence: "review of statistical methodologies for the detection of parent-of-origin effects in family trio genome-wide association data with binary disease traits." - 20 Tokens
#
#   ## Candidate 6265, score 0.8406670689582825
#   Sentence: "sv-autopilot: optimized, automated construction of structural variation discovery and benchmarking pipelines." - 11 Tokens
#
#   ## Candidate 1409, score 0.8365575671195984
#   Sentence: "wfabc: a wright-fisher abc-based approach for inferring effective population sizes and selection coefficients from time-sampled data." - 16 Tokens
#
#   ## Candidate 8276, score 0.8311638236045837
#   Sentence: "an empiric weight computation for record linkage using linearly combined fields' similarity scores." - 13 Tokens
#
#   ## Candidate 2656, score 0.8308850526809692
#   Sentence: "panet: a gpu-based tool for fast parallel analysis of robustness dynamics and feed-forward/feedback loop structures in large-scale biological networks." - 19 Tokens
#
#
#
#
# # Query 6
# Sentence: "MELODI: Mining Enriched Literature Objects to Derive Intermediates" - 8 Tokens
#   ## Candidate 1970, score 0.7248488068580627
#   Sentence: "the use of research electronic data capture (redcap) software to create a database of librarian-mediated literature searches." - 17 Tokens
#
#   ## Candidate 6265, score 0.7127289175987244
#   Sentence: "sv-autopilot: optimized, automated construction of structural variation discovery and benchmarking pipelines." - 11 Tokens
#
#   ## Candidate 8276, score 0.7114076614379883
#   Sentence: "an empiric weight computation for record linkage using linearly combined fields' similarity scores." - 13 Tokens
#
#   ## Candidate 7328, score 0.7097719311714172
#   Sentence: "chippcr: an r package to pre-process raw data of amplification curves." - 11 Tokens
#
#   ## Candidate 397, score 0.7040315270423889
#   Sentence: "metadata extraction routines for improving infobutton performance." - 7 Tokens
#
#
#
#
# # Query 7
# Sentence: "The MR-Base platform supports systematic causal inference across the human phenome" - 11 Tokens
#   ## Candidate 2656, score 0.8485689163208008
#   Sentence: "panet: a gpu-based tool for fast parallel analysis of robustness dynamics and feed-forward/feedback loop structures in large-scale biological networks." - 19 Tokens
#
#   ## Candidate 6265, score 0.8256068229675293
#   Sentence: "sv-autopilot: optimized, automated construction of structural variation discovery and benchmarking pipelines." - 11 Tokens
#
#   ## Candidate 8950, score 0.821424126625061
#   Sentence: "reconstruction of genome-scale human metabolic models using omics data." - 9 Tokens
#
#   ## Candidate 6023, score 0.8201123476028442
#   Sentence: "accounting for genetic architecture improves sequence based genomic prediction for a drosophila fitness trait." - 14 Tokens
#
#   ## Candidate 8039, score 0.8192753791809082
#   Sentence: "integrated analysis of transcriptomic and proteomic datasets reveals information on protein expressivity and factors affecting translational efficiency." - 17 Tokens
